# %% [markdown]
# # Introduction

# %% [markdown]
# The dot product (also known as the scalar product) in NumPy can be applied to vectors and matrices, and it plays a fundamental role in linear algebra, machine learning, and scientific computing. Let's explore how the dot product works for different scenarios: vector-vector, vector-matrix, and matrix-matrix multiplications using NumPy.
#
# 1. Vector-Vector Multiplication
# The dot product of two vectors results in a scalar value. The formula for the dot product of two vectors
#
# 2. Vector-Matrix Multiplication
# The dot product between a vector and a matrix results in a new vector. If
# 𝑎
# a is a 1D vector and
# 𝑀
# M is a 2D matrix, the result is a vector
# 𝑣
# v where each element is the dot product of
# 𝑎
# a with the corresponding column (or row, depending on the dimensions) of
# 𝑀
# M.
#
# 3. Matrix-Matrix Multiplication
# The dot product between two matrices
# 𝐴
# A and
# 𝐵
# B results in a new matrix
# 𝐶
# C, where each element
# 𝑐
# 𝑖
# 𝑗
# c
# ij
# ​
#   is the dot product of the
# 𝑖
# i-th row of
# 𝐴
# A and the
# 𝑗
# j-th column of
# 𝐵
# B.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Importing the libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Single Neuron Usng Numpy

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Define two vectors
inputs = np.array([1, 2, 3])
weights = np.array([4, 5, 6])

bias = 2

# Dot product
result = np.dot(inputs, weights) + bias
# or
result = inputs @ weights + bias

print(result)
# Out:
# 34

# %% [markdown]
# # Layer Of Neuron

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Define a vector and a matrix
inputs = np.array([1, 2, 3, 4])
weights = np.array([[1, 2, 3, 4],
              [4, 5, 6, 9],
              [7, 8, 9, 20]])

## In the weights matrix , each row denotes the weights corresponding to a single neuron

bias = np.array([0.1,0.2,0.3])
bias = np.transpose(bias)

# Dot product
result = np.dot(weights, inputs) + bias
# or
result2 = np.dot(inputs, np.transpose(weights)) + np.transpose(bias)

print(result)  # Output: [30 36 42]
print(result2)
# Out:
# [ 30.1  68.2 130.3]
# [ 30.1  68.2 130.3]

# %% [markdown]
# # Batch of Data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Define two matrices
inputs = np.array([[1, 2,6 ,8],
              [1, 2,66 ,8],
              [1, 42,6 ,8],
              [1, 2,6 ,88]])


#3 We have 3 neurons in the input layer , so for each neuron , no of weights will be equal to no of inputs
weights = np.array([[5, 6, 2,3],
              [5, 68, 2,3],
              [5, 26, 2,3]
                    ])
bias = np.array([0.1,0.2,0.3])
# Dot product
result = np.dot(inputs, np.transpose(weights)) + bias

print(result)
# Output:
# [[19 22]
#  [43 50]]
# Out:
# [[  53.1  177.2   93.3]
#  [ 173.1  297.2  213.3]
#  [ 293.1 2897.2 1133.3]
#  [ 293.1  417.2  333.3]]

# %%
weights = np.array([[5, 6, 2,3],
              [5, 68, 2,3],
              [5, 26, 2,3]
                    ])
bias = np.array([0.1,0.2,0.3,0.4])

weights + bias
# Out:
# array([[ 5.1,  6.2,  2.3,  3.4],
#        [ 5.1, 68.2,  2.3,  3.4],
#        [ 5.1, 26.2,  2.3,  3.4]])
